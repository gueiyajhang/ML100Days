# %% [markdown]
# ### 作業目標: 使用Jieba進行各項的斷詞操作

# %%
pip install -U ckiptagger[tf,gdown]
# Out:
# Requirement already up-to-date: ckiptagger[gdown,tf] in c:\users\queiy\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied, skipping upgrade: gdown; extra == "gdown" in c:\users\queiy\anaconda3\lib\site-packages (from ckiptagger[gdown,tf]) (3.12.2)
# Requirement already satisfied, skipping upgrade: tensorflow>=1.13.1; extra == "tf" in c:\users\queiy\anaconda3\lib\site-packages (from ckiptagger[gdown,tf]) (2.2.0)
# Requirement already satisfied, skipping upgrade: requests[socks] in c:\users\queiy\anaconda3\lib\site-packages (from gdown; extra == "gdown"->ckiptagger[gdown,tf]) (2.22.0)
# Requirement already satisfied, skipping upgrade: filelock in c:\users\queiy\anaconda3\lib\site-packages (from gdown; extra == "gdown"->ckiptagger[gdown,tf]) (3.0.12)
# Requirement already satisfied, skipping upgrade: tqdm in c:\users\queiy\anaconda3\lib\site-packages (from gdown; extra == "gdown"->ckiptagger[gdown,tf]) (4.36.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\queiy\anaconda3\lib\site-packages (from gdown; extra == "gdown"->ckiptagger[gdown,tf]) (1.12.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (3.12.2)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.16.5)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.29.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.33.6)
# Requirement already satisfied, skipping upgrade: scipy==1.4.1; python_version >= "3" in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.4.1)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (3.2.1)
# Requirement already satisfied, skipping upgrade: astunparse==1.6.3 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.6.3)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.3.0,>=2.2.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (2.2.0)
# Requirement already satisfied, skipping upgrade: h5py<2.11.0,>=2.10.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (2.10.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.1.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.1.2)
# Requirement already satisfied, skipping upgrade: tensorboard<2.3.0,>=2.2.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (2.2.2)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.1.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.2.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.9.0)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.3.3)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in c:\users\queiy\anaconda3\lib\site-packages (from tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.11.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\queiy\anaconda3\lib\site-packages (from requests[socks]->gdown; extra == "gdown"->ckiptagger[gdown,tf]) (2019.9.11)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\queiy\anaconda3\lib\site-packages (from requests[socks]->gdown; extra == "gdown"->ckiptagger[gdown,tf]) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\queiy\anaconda3\lib\site-packages (from requests[socks]->gdown; extra == "gdown"->ckiptagger[gdown,tf]) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\queiy\anaconda3\lib\site-packages (from requests[socks]->gdown; extra == "gdown"->ckiptagger[gdown,tf]) (1.24.2)
# Requirement already satisfied, skipping upgrade: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\queiy\anaconda3\lib\site-packages (from requests[socks]->gdown; extra == "gdown"->ckiptagger[gdown,tf]) (1.7.1)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\queiy\anaconda3\lib\site-packages (from protobuf>=3.8.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (41.4.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\queiy\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.4.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in c:\users\queiy\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.16.0)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in c:\users\queiy\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.6.0.post3)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in c:\users\queiy\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.16.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in c:\users\queiy\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (3.2.2)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in c:\users\queiy\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\queiy\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.2.7)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in c:\users\queiy\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in c:\users\queiy\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (4.1.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in c:\users\queiy\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.23)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in c:\users\queiy\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\users\queiy\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.4.8)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in c:\users\queiy\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (0.6.0)
# Requirement already satisfied, skipping upgrade: more-itertools in c:\users\queiy\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow>=1.13.1; extra == "tf"->ckiptagger[gdown,tf]) (7.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import 所需 libraries

# %%
#導入所需libraries
#請import 1.可用於下載權重的library 2.建構自定義字典的library 3.斷詞, 詞性標注,與命名實體辨識libries
###<your code>###
import numpy as np
import ckiptagger
from ckiptagger import data_utils, WS, POS, NER
# data_utils.download_data_gdown("./")



#請對下列文本字串進行斷詞, 詞性標注, 命名實體識別

sentence_list = [
    "傅達仁今將執行安樂死，卻突然爆出自己20年前遭緯來體育台封殺，他不懂自己哪裡得罪到電視台。",
    "美國參議院針對今天總統布什所提名的勞工部長趙小蘭展開認可聽證會，預料她將會很順利通過參議院支持，成為該國有史以來第一位的華裔女性內閣成員。",
    "",
    "土地公有政策?？還是土地婆有政策。.",
    "… 你確定嗎… 不要再騙了……",
    "最多容納59,000個人,或5.9萬人,再多就不行了.這是環評的結論.",
    "科長說:1,坪數對人數為1:3。2,可以再增加。",
]

# %% [markdown]
# ### 進行斷詞, 詞性標注, 與命名實體識別

# %%
#創建實例
ws = WS("./D07data")
pos = POS("./D07data")
ner = NER("./D07data")

#建構斷詞
input_string = sentence_list
word_s = ws(
    sentence_list,
    sentence_segmentation = True, # To consider delimiters
    segment_delimiter_set = {",", "。", ":", "?", "!", ";"}) # This is the defualt set of delimiters

print(f'斷詞輸出: {word_s}')
print('\n')

#詞性標注
word_p = pos(word_sentence_list)

print(f'詞性標注輸出: {word_p}')
print('\n')

#命名實體識別
word_n = ner(word_sentence_list, pos_sentence_list)
print(f'命名實體識別輸出: {word_n}')
# Out:
# 斷詞輸出: [['傅達仁', '今', '將', '執行', '安樂死', '，', '卻', '突然', '爆出', '自己', '20', '年', '前', '遭', '緯來', '體育台', '封殺', '，', '他', '不', '懂', '自己', '哪裡', '得罪到', '電視台', '。'], ['美國', '參議院', '針對', '今天', '總統', '布什', '所', '提名', '的', '勞工部長', '趙小蘭', '展開', '認可', '聽證會', '，', '預料', '她', '將', '會', '很', '順利', '通過', '參議院', '支持', '，', '成為', '該', '國', '有史以來', '第一', '位', '的', '華裔', '女性', '內閣', '成員', '。'], [], ['土地公', '有', '政策', '?', '？', '還是', '土地', '婆', '有', '政策', '。', '.'], ['…', ' ', '你', '確定', '嗎', '…', ' ', '不要', '再', '騙', '了', '…', '…'], ['最多', '容納', '59', ',', '000', '個', '人', ',', '或', '5.9萬', '人', ',', '再', '多', '就', '不行', '了', '.', '這', '是', '環評', '的', '結論', '.'], ['科長', '說', ':', '1', ',', '坪數', '對', '人數', '為', '1', ':', '3', '。', '2', ',', '可以', '再', '增加', '。']]
#
#
# 詞性標注輸出: [['Nb', 'Nd', 'D', 'VC', 'Na', 'COMMACATEGORY', 'D', 'D', 'VJ', 'Nh', 'Neu', 'Nf', 'Ng', 'P', 'Nb', 'Na', 'VC', 'COMMACATEGORY', 'Nh', 'D', 'VK', 'Nh', 'Ncd', 'VJ', 'Nc', 'PERIODCATEGORY'], ['Nc', 'Nc', 'P', 'Nd', 'Na', 'Nb', 'D', 'VC', 'DE', 'Na', 'Nb', 'VC', 'VC', 'Na', 'COMMACATEGORY', 'VE', 'Nh', 'D', 'D', 'Dfa', 'VH', 'VC', 'Nc', 'VC', 'COMMACATEGORY', 'VG', 'Nes', 'Nc', 'D', 'Neu', 'Nf', 'DE', 'Na', 'Na', 'Na', 'Na', 'PERIODCATEGORY'], [], ['Nb', 'V_2', 'Na', 'QUESTIONCATEGORY', 'QUESTIONCATEGORY', 'Caa', 'Na', 'Na', 'V_2', 'Na', 'PERIODCATEGORY', 'PERIODCATEGORY'], ['ETCCATEGORY', 'WHITESPACE', 'Nh', 'VK', 'T', 'ETCCATEGORY', 'WHITESPACE', 'D', 'D', 'VC', 'Di', 'ETCCATEGORY', 'ETCCATEGORY'], ['VH', 'VJ', 'Neu', 'COMMACATEGORY', 'Neu', 'Nf', 'Na', 'COMMACATEGORY', 'Caa', 'Neu', 'Na', 'COMMACATEGORY', 'D', 'D', 'D', 'VH', 'T', 'PERIODCATEGORY', 'Nep', 'SHI', 'Na', 'DE', 'Na', 'PERIODCATEGORY'], ['Na', 'VE', 'COLONCATEGORY', 'Neu', 'COMMACATEGORY', 'Na', 'P', 'Na', 'VG', 'Neu', 'COLONCATEGORY', 'Neu', 'PERIODCATEGORY', 'Neu', 'COMMACATEGORY', 'D', 'D', 'VHC', 'PERIODCATEGORY']]
#
#
# 命名實體識別輸出: [{(0, 3, 'PERSON', '傅達仁'), (18, 22, 'DATE', '20年前'), (23, 28, 'ORG', '緯來體育台')}, {(7, 9, 'DATE', '今天'), (56, 58, 'ORDINAL', '第一'), (2, 5, 'ORG', '參議院'), (0, 2, 'GPE', '美國'), (60, 62, 'NORP', '華裔'), (11, 13, 'PERSON', '布什'), (21, 24, 'PERSON', '趙小蘭'), (17, 21, 'ORG', '勞工部長'), (42, 45, 'ORG', '參議院')}, set(), {(0, 3, 'PERSON', '土地公')}, set(), {(7, 10, 'CARDINAL', '000'), (4, 6, 'CARDINAL', '59'), (14, 18, 'CARDINAL', '5.9萬')}, {(14, 15, 'CARDINAL', '3'), (12, 13, 'CARDINAL', '1'), (16, 17, 'CARDINAL', '2'), (4, 5, 'CARDINAL', '1')}]

# %%
#合併顯示輸出結果
def combine_wandp(word_s, word_p):
    assert len(word_s) == len(word_p)
    
    for word, pos in zip(word_s, word_p):
        print(f"{word}({pos})", end="\u3000")
    print()
    return
        
for i, sentence in enumerate(sentence_list):
    print(f'Input sentence: \n {sentence}')
    print('\n')
    
    print(f'Segmentation with PoS: \n')
    combine_wandp(word_sentence_list[i],  pos_sentence_list[i])
    for entity in sorted(entity_sentence_list[i]):
        print(entity)
    
    print ('\n')
    print('Named Entity Recognition:')
    for n in sorted(word_n[i]):
        print (n)
    print ('\n')
# Out:
# Input sentence:
#  傅達仁今將執行安樂死，卻突然爆出自己20年前遭緯來體育台封殺，他不懂自己哪裡得罪到電視台。
#
#
# Segmentation with PoS:
#
# 傅達仁(Nb)　今(Nd)　將(D)　執行(VC)　安樂死(Na)　，(COMMACATEGORY)　卻(D)　突然(D)　爆出(VJ)　自己(Nh)　20(Neu)　年(Nf)　前(Ng)　遭(P)　緯來(Nb)　體育台(Na)　封殺(VC)　，(COMMACATEGORY)　他(Nh)　不(D)　懂(VK)　自己(Nh)　哪裡(Ncd)　得罪到(VJ)　電視台(Nc)　。(PERIODCATEGORY)
# (0, 3, 'PERSON', '傅達仁')
# (18, 22, 'DATE', '20年前')
# (23, 28, 'ORG', '緯來體育台')
#
#
# Named Entity Recognition:
# (0, 3, 'PERSON', '傅達仁')
# (18, 22, 'DATE', '20年前')
# (23, 28, 'ORG', '緯來體育台')
#
#
# Input sentence:
#  美國參議院針對今天總統布什所提名的勞工部長趙小蘭展開認可聽證會，預料她將會很順利通過參議院支持，成為該國有史以來第一位的華裔女性內閣成員。
#
#
# Segmentation with PoS:
#
# 美國(Nc)　參議院(Nc)　針對(P)　今天(Nd)　總統(Na)　布什(Nb)　所(D)　提名(VC)　的(DE)　勞工部長(Na)　趙小蘭(Nb)　展開(VC)　認可(VC)　聽證會(Na)　，(COMMACATEGORY)　預料(VE)　她(Nh)　將(D)　會(D)　很(Dfa)　順利(VH)　通過(VC)　參議院(Nc)　支持(VC)　，(COMMACATEGORY)　成為(VG)　該(Nes)　國(Nc)　有史以來(D)　第一(Neu)　位(Nf)　的(DE)　華裔(Na)　女性(Na)　內閣(Na)　成員(Na)　。(PERIODCATEGORY)
# (0, 2, 'GPE', '美國')
# (2, 5, 'ORG', '參議院')
# (7, 9, 'DATE', '今天')
# (11, 13, 'PERSON', '布什')
# (17, 21, 'ORG', '勞工部長')
# (21, 24, 'PERSON', '趙小蘭')
# (42, 45, 'ORG', '參議院')
# (56, 58, 'ORDINAL', '第一')
# (60, 62, 'NORP', '華裔')
#
#
# Named Entity Recognition:
# (0, 2, 'GPE', '美國')
# (2, 5, 'ORG', '參議院')
# (7, 9, 'DATE', '今天')
# (11, 13, 'PERSON', '布什')
# (17, 21, 'ORG', '勞工部長')
# (21, 24, 'PERSON', '趙小蘭')
# (42, 45, 'ORG', '參議院')
# (56, 58, 'ORDINAL', '第一')
# (60, 62, 'NORP', '華裔')
#
#
# Input sentence:
#
#
#
# Segmentation with PoS:
#
#
#
#
# Named Entity Recognition:
#
#
# Input sentence:
#  土地公有政策?？還是土地婆有政策。.
#
#
# Segmentation with PoS:
#
# 土地公(Nb)　有(V_2)　政策(Na)　?(QUESTIONCATEGORY)　？(QUESTIONCATEGORY)　還是(Caa)　土地(Na)　婆(Na)　有(V_2)　政策(Na)　。(PERIODCATEGORY)　.(PERIODCATEGORY)
# (0, 3, 'PERSON', '土地公')
#
#
# Named Entity Recognition:
# (0, 3, 'PERSON', '土地公')
#
#
# Input sentence:
#  … 你確定嗎… 不要再騙了……
#
#
# Segmentation with PoS:
#
# …(ETCCATEGORY)　 (WHITESPACE)　你(Nh)　確定(VK)　嗎(T)　…(ETCCATEGORY)　 (WHITESPACE)　不要(D)　再(D)　騙(VC)　了(Di)　…(ETCCATEGORY)　…(ETCCATEGORY)
#
#
# Named Entity Recognition:
#
#
# Input sentence:
#  最多容納59,000個人,或5.9萬人,再多就不行了.這是環評的結論.
#
#
# Segmentation with PoS:
#
# 最多(VH)　容納(VJ)　59(Neu)　,(COMMACATEGORY)　000(Neu)　個(Nf)　人(Na)　,(COMMACATEGORY)　或(Caa)　5.9萬(Neu)　人(Na)　,(COMMACATEGORY)　再(D)　多(D)　就(D)　不行(VH)　了(T)　.(PERIODCATEGORY)　這(Nep)　是(SHI)　環評(Na)　的(DE)　結論(Na)　.(PERIODCATEGORY)
# (4, 6, 'CARDINAL', '59')
# (7, 10, 'CARDINAL', '000')
# (14, 18, 'CARDINAL', '5.9萬')
#
#
# Named Entity Recognition:
# (4, 6, 'CARDINAL', '59')
# (7, 10, 'CARDINAL', '000')
# (14, 18, 'CARDINAL', '5.9萬')
#
#
# Input sentence:
#  科長說:1,坪數對人數為1:3。2,可以再增加。
#
#
# Segmentation with PoS:
#
# 科長(Na)　說(VE)　:(COLONCATEGORY)　1(Neu)　,(COMMACATEGORY)　坪數(Na)　對(P)　人數(Na)　為(VG)　1(Neu)　:(COLONCATEGORY)　3(Neu)　。(PERIODCATEGORY)　2(Neu)　,(COMMACATEGORY)　可以(D)　再(D)　增加(VHC)　。(PERIODCATEGORY)
# (4, 5, 'CARDINAL', '1')
# (12, 13, 'CARDINAL', '1')
# (14, 15, 'CARDINAL', '3')
# (16, 17, 'CARDINAL', '2')
#
#
# Named Entity Recognition:
# (4, 5, 'CARDINAL', '1')
# (12, 13, 'CARDINAL', '1')
# (14, 15, 'CARDINAL', '3')
# (16, 17, 'CARDINAL', '2')

# %% [markdown]
# ### 帶入自定義字典
#
# 觀察上面的輸出發現，斷詞結果將`年前`斷為`年`、`前`, 請使用自定義字典使斷詞結果依然維持為`年前`

# %%
#定義字典
# import library
from ckiptagger import construct_dictionary

#定義自定義字典
#每個字對應的數值為其相對權重

word_to_weight = {
    "年": 1,
    "前": 1,
}
dictionary1 = construct_dictionary(word_to_weight)
print(dictionary1)


word_to_weight = {
    "年前": 1
}
dictionary2 = construct_dictionary(word_to_weight)
print(dictionary2)

#帶入自定義字典進行斷詞
ws1 = WS("./D07data") #建構斷詞

input_traditional_str = ["傅達仁今將執行安樂死，卻突然爆出自己20年前遭緯來體育台封殺，他不懂自己哪裡得罪到電視台。"]

word_sentence_list = ws1(
    input_traditional_str,
    sentence_segmentation = True, # To consider delimiters
    segment_delimiter_set = {",", "。", ":", "?", "!", ";"}, # This is the defualt set of delimiters
    recommend_dictionary = dictionary1, # words in this dictionary are encouraged
    coerce_dictionary = dictionary2) # words in this dictionary are forced


print(word_sentence_list)
# Out:
# [(1, {'年': 1.0, '前': 1.0})]
# [(2, {'年前': 1.0})]
# [['傅達仁', '今', '將', '執行', '安樂死', '，', '卻', '突然', '爆出', '自己', '20', '年前', '遭', '緯來', '體育台', '封殺', '，', '他', '不', '懂', '自己', '哪裡', '得罪到', '電視台', '。']]
