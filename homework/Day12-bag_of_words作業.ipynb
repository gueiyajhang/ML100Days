# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
nltk.download('punkt')
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)
whole_words[:5]
# Out:
# ['Wow', '...', 'Loved', 'this', 'place']

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n 
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'IN': 0,
#  'deserves': 1,
#  'best': 2,
#  'reasons': 3,
#  'chow': 4,
#  'take': 5,
#  'pepper': 6,
#  'Really': 7,
#  'end': 8,
#  'Horrible': 9,
#  'Japanese': 10,
#  'Luke': 11,
#  'stuff': 12,
#  'older': 13,
#  'tragedy': 14,
#  'meals': 15,
#  'Experience': 16,
#  'Your': 17,
#  'pink': 18,
#  'batter': 19,
#  'disaster': 20,
#  'personally': 21,
#  'brunch': 22,
#  'perpared': 23,
#  'mistake': 24,
#  'crêpe': 25,
#  'worker': 26,
#  'Good': 27,
#  'regularly': 28,
#  'must-stop': 29,
#  'judging': 30,
#  'warnings': 31,
#  'fresh': 32,
#  'Crostini': 33,
#  'salt': 34,
#  'fairly': 35,
#  'melted': 36,
#  'gem': 37,
#  'crawfish': 38,
#  'tribute': 39,
#  'Overall': 40,
#  'money': 41,
#  'market': 42,
#  'lunch': 43,
#  'mussels': 44,
#  'Sun': 45,
#  'ahead': 46,
#  'Burrittos': 47,
#  'attitudes': 48,
#  'Madison': 49,
#  'beans': 50,
#  'Ambience': 51,
#  'Paradise': 52,
#  'Pizza': 53,
#  'summarize': 54,
#  'portion': 55,
#  'whenever': 56,
#  'before': 57,
#  'know': 58,
#  'not': 59,
#  'Firehouse': 60,
#  'Magazine': 61,
#  'awkwardly': 62,
#  'services': 63,
#  'ten': 64,
#  'six': 65,
#  '10': 66,
#  'pepper..and': 67,
#  'GREAT': 68,
#  'Toast': 69,
#  'where': 70,
#  'simply': 71,
#  'Level': 72,
#  'hoping': 73,
#  'begin': 74,
#  'wonderful': 75,
#  'cakes': 76,
#  'Mandalay': 77,
#  'Tucson': 78,
#  'me': 79,
#  'chefs': 80,
#  'Eew': 81,
#  'crab': 82,
#  'fell': 83,
#  'pretty': 84,
#  'summary': 85,
#  'NONE': 86,
#  'kitchen': 87,
#  'feels': 88,
#  'Terrible': 89,
#  'Oh': 90,
#  'Pretty': 91,
#  'pack': 92,
#  'person': 93,
#  'enthusiastic': 94,
#  'dropped': 95,
#  'Will': 96,
#  'Greek': 97,
#  'patty': 98,
#  'without': 99,
#  'blandest': 100,
#  'huevos': 101,
#  'Hunan': 102,
#  'horrible': 103,
#  'classic': 104,
#  'sliced': 105,
#  'palate': 106,
#  'takeout': 107,
#  'gristle': 108,
#  'avoided': 109,
#  'black': 110,
#  'recent': 111,
#  'mmmm': 112,
#  'scallop': 113,
#  'Caesar': 114,
#  'ranch': 115,
#  'deal': 116,
#  'FLAVOR': 117,
#  'reminded': 118,
#  'salty': 119,
#  'opposed': 120,
#  'serves': 121,
#  'maintaining': 122,
#  'guys': 123,
#  'raspberry': 124,
#  '7.85': 125,
#  '.THE': 126,
#  'tapas': 127,
#  'ridiculous': 128,
#  'ordering': 129,
#  'last': 130,
#  'hour': 131,
#  'menu/': 132,
#  'quickly': 133,
#  'Cant': 134,
#  'crispy': 135,
#  'that': 136,
#  'giving': 137,
#  'BACK': 138,
#  'impeccable': 139,
#  'Christmas': 140,
#  'letting': 141,
#  'lighter': 142,
#  'Coffee': 143,
#  'olives': 144,
#  'time': 145,
#  'self': 146,
#  'saganaki': 147,
#  'first': 148,
#  'sexy': 149,
#  'jalapeno': 150,
#  'Worst': 151,
#  'gone': 152,
#  'There': 153,
#  'small': 154,
#  'seafood': 155,
#  'Prices': 156,
#  'compliments': 157,
#  'huge': 158,
#  'stay': 159,
#  'dishes': 160,
#  'getting': 161,
#  'crumby': 162,
#  'here': 163,
#  'send': 164,
#  'Sprouts': 165,
#  'wo': 166,
#  'entire': 167,
#  'left': 168,
#  'vegetarian': 169,
#  'mein': 170,
#  'disagree': 171,
#  'management': 172,
#  'beyond': 173,
#  'honor': 174,
#  'thanks': 175,
#  'sandwich': 176,
#  'Soups': 177,
#  'under': 178,
#  'Wife': 179,
#  'Bean': 180,
#  'sandwiches': 181,
#  'highlight': 182,
#  'orders': 183,
#  'pecan': 184,
#  'strange': 185,
#  'airline': 186,
#  'lighting': 187,
#  'One': 188,
#  'cook': 189,
#  'Buldogis': 190,
#  'found': 191,
#  'Before': 192,
#  'Chipotle': 193,
#  'went': 194,
#  'thinly': 195,
#  'eggplant': 196,
#  'living': 197,
#  'Awful': 198,
#  'trimmed': 199,
#  'touch': 200,
#  'dirty': 201,
#  'helped': 202,
#  'Up': 203,
#  'passed': 204,
#  'stretch': 205,
#  'sauce': 206,
#  'enough..': 207,
#  'Classy/warm': 208,
#  'EXPERIENCE': 209,
#  'fine': 210,
#  'gas': 211,
#  'seems': 212,
#  'way': 213,
#  'super': 214,
#  'caught': 215,
#  'Bachi': 216,
#  'delicious': 217,
#  'club': 218,
#  'delicate': 219,
#  'to': 220,
#  'RI': 221,
#  'trip': 222,
#  'douchey': 223,
#  'for': 224,
#  'grocery': 225,
#  'since': 226,
#  'cocktails': 227,
#  'haunt': 228,
#  'thinking': 229,
#  'tots': 230,
#  'couple': 231,
#  'Macarons': 232,
#  'mom': 233,
#  'screwed': 234,
#  'disgrace': 235,
#  'boot': 236,
#  'couples': 237,
#  'WAY': 238,
#  'given': 239,
#  'low': 240,
#  'we': 241,
#  'rich': 242,
#  'customer': 243,
#  'pancake': 244,
#  'apple': 245,
#  'Crystals': 246,
#  'friends': 247,
#  'employees': 248,
#  'complain': 249,
#  'nothing': 250,
#  'accountant': 251,
#  'ALL': 252,
#  'Waited': 253,
#  'bone': 254,
#  "ya'all": 255,
#  'was': 256,
#  'much': 257,
#  'Unfortunately': 258,
#  'each': 259,
#  'one': 260,
#  'flavourful': 261,
#  'together': 262,
#  'drunk': 263,
#  'driving': 264,
#  'over-whelm': 265,
#  'largely': 266,
#  'summer': 267,
#  'tea': 268,
#  'outta': 269,
#  'vegetables': 270,
#  'drinks': 271,
#  'fare': 272,
#  'crisp': 273,
#  'make': 274,
#  'can': 275,
#  'Love': 276,
#  'cheek': 277,
#  'bathrooms': 278,
#  'spots': 279,
#  'nigiri': 280,
#  'continue': 281,
#  'THIS': 282,
#  'frozen': 283,
#  'refrained': 284,
#  'dripping': 285,
#  'ball': 286,
#  'daughter': 287,
#  'party': 288,
#  'owner/chef': 289,
#  'ache': 290,
#  'On': 291,
#  'taste': 292,
#  'Rick': 293,
#  'GC': 294,
#  'Went': 295,
#  'public': 296,
#  'brownish': 297,
#  'Of': 298,
#  'fillet': 299,
#  'spice': 300,
#  'yummy': 301,
#  'over': 302,
#  'latte': 303,
#  'desired': 304,
#  'year': 305,
#  'little': 306,
#  'Im': 307,
#  'dates': 308,
#  'offers': 309,
#  'Place': 310,
#  'meat': 311,
#  'fish': 312,
#  'Smashburger': 313,
#  'playing': 314,
#  'Then': 315,
#  'leather': 316,
#  'smeared': 317,
#  'anyone': 318,
#  'Delicious': 319,
#  'easily': 320,
#  'GO': 321,
#  'ever': 322,
#  'friendly': 323,
#  'PEOPLE': 324,
#  'listed': 325,
#  'brother': 326,
#  'break': 327,
#  'real': 328,
#  'sucker': 329,
#  'multi-grain': 330,
#  'asking': 331,
#  'ago': 332,
#  'editing': 333,
#  'lacked': 334,
#  'relaxed': 335,
#  'combination': 336,
#  'disapppointment': 337,
#  'dry': 338,
#  'place': 339,
#  'signs': 340,
#  'felt': 341,
#  'toro': 342,
#  'possible': 343,
#  'appalling': 344,
#  'shoe': 345,
#  'corn': 346,
#  'steaks': 347,
#  'eating': 348,
#  'Scottsdale': 349,
#  'theft': 350,
#  'all': 351,
#  'awkward': 352,
#  'recommendation': 353,
#  'tartare': 354,
#  'touched': 355,
#  'Disappointing': 356,
#  'live': 357,
#  'calligraphy': 358,
#  'special': 359,
#  'Frenchman': 360,
#  'least': 361,
#  'house': 362,
#  'pats': 363,
#  'T.': 364,
#  'might': 365,
#  'blanket': 366,
#  'gyros': 367,
#  'gave': 368,
#  'batch': 369,
#  'fail': 370,
#  'Cooked': 371,
#  'loudly': 372,
#  'looks': 373,
#  'For': 374,
#  '!': 375,
#  'sorely': 376,
#  'tip': 377,
#  'speedy': 378,
#  'desserts': 379,
#  'Camelback': 380,
#  'stayed': 381,
#  'healthy': 382,
#  'bellies': 383,
#  'relocated': 384,
#  'Strip': 385,
#  'Eclectic': 386,
#  'play': 387,
#  'boy': 388,
#  'fondue': 389,
#  'WORST': 390,
#  'who': 391,
#  'things': 392,
#  'military': 393,
#  'thought': 394,
#  'need': 395,
#  'courteous': 396,
#  'wall': 397,
#  'stuffed': 398,
#  'drive': 399,
#  'WAAAAAAyyyyyyyyyy': 400,
#  'perfection': 401,
#  'Eve': 402,
#  'coupons': 403,
#  'mary': 404,
#  '..went': 405,
#  '*': 406,
#  'damn': 407,
#  'slaw': 408,
#  'publicly': 409,
#  'deuchebaggery': 410,
#  'STEP': 411,
#  'extra': 412,
#  'judge': 413,
#  'rancheros': 414,
#  'informative': 415,
#  'Hard': 416,
#  'imaginative': 417,
#  'rib': 418,
#  'pancakes': 419,
#  'charge': 420,
#  'Baseball': 421,
#  'fiancé': 422,
#  'down': 423,
#  'missed': 424,
#  'tiny': 425,
#  'Fantastic': 426,
#  'Highly': 427,
#  'Gyros': 428,
#  'Avoid': 429,
#  'kids': 430,
#  'reduction': 431,
#  'When': 432,
#  'wagyu': 433,
#  'trying': 434,
#  'duo': 435,
#  'meatballs': 436,
#  'Everything': 437,
#  'breaks': 438,
#  'Lobster': 439,
#  'Pros': 440,
#  'door': 441,
#  'out': 442,
#  'mouths': 443,
#  'wings': 444,
#  'checked': 445,
#  'REALLY': 446,
#  'heart': 447,
#  'closed': 448,
#  'Seat': 449,
#  'Never': 450,
#  'North': 451,
#  'warm': 452,
#  'ask': 453,
#  'Cartel': 454,
#  'soundtrack': 455,
#  'included': 456,
#  'pneumatic': 457,
#  'head': 458,
#  'meet': 459,
#  'work': 460,
#  'by': 461,
#  'deep': 462,
#  'Frozen': 463,
#  'helpful': 464,
#  'kid': 465,
#  'gold': 466,
#  'FLY': 467,
#  'expected': 468,
#  'shawarrrrrrma': 469,
#  'promptly': 470,
#  'carpaccio': 471,
#  'look': 472,
#  'prime': 473,
#  'writing': 474,
#  'patio': 475,
#  'mediocre': 476,
#  'effort': 477,
#  'crowd': 478,
#  'sat': 479,
#  'wide': 480,
#  'Heimer': 481,
#  'FS': 482,
#  'UNREAL': 483,
#  'Sour': 484,
#  'thrilled': 485,
#  'disrespected': 486,
#  'opportunity': 487,
#  'saving': 488,
#  'generous': 489,
#  'large': 490,
#  'nicest': 491,
#  'violinists': 492,
#  'happier': 493,
#  'Jenni': 494,
#  'you': 495,
#  'section': 496,
#  'hello': 497,
#  'besides': 498,
#  'rubber': 499,
#  'kind': 500,
#  'salsa': 501,
#  'Bland': 502,
#  'callings': 503,
#  '70+': 504,
#  'Edinburgh': 505,
#  'block': 506,
#  'longer': 507,
#  'fluffy': 508,
#  'Nice': 509,
#  'cramming': 510,
#  'vinaigrette': 511,
#  'either': 512,
#  'EVER': 513,
#  'falafels': 514,
#  'his': 515,
#  'try': 516,
#  'realized': 517,
#  'FORWARD': 518,
#  'glance': 519,
#  'remember': 520,
#  'indoor': 521,
#  'decision': 522,
#  'disappointing': 523,
#  '..there': 524,
#  'dedicated': 525,
#  'pace': 526,
#  '-Drinks': 527,
#  '2': 528,
#  "'re": 529,
#  'handling': 530,
#  'ok': 531,
#  'watered': 532,
#  'owners': 533,
#  'hungry': 534,
#  'grossed': 535,
#  'seal': 536,
#  'massive': 537,
#  'Check': 538,
#  'Nobu': 539,
#  'disappointment': 540,
#  'fruit': 541,
#  'scene': 542,
#  'waiting': 543,
#  'once': 544,
#  'Restaurant': 545,
#  'Bay': 546,
#  'personable': 547,
#  'Lordy': 548,
#  'check': 549,
#  'of': 550,
#  'cant': 551,
#  'Joey': 552,
#  'fella': 553,
#  'flat': 554,
#  'banana': 555,
#  'Tasty': 556,
#  'complaints': 557,
#  'stir': 558,
#  'profiterole': 559,
#  'college': 560,
#  'dessert': 561,
#  'HAPPENED': 562,
#  'sunglasses': 563,
#  'today': 564,
#  'edible': 565,
#  'later': 566,
#  'hilarious': 567,
#  'highlighted': 568,
#  'email': 569,
#  'quaint': 570,
#  'NEVER': 571,
#  'class': 572,
#  'welcome': 573,
#  'Some': 574,
#  'Weird': 575,
#  'what': 576,
#  'angry': 577,
#  'same': 578,
#  'Roll': 579,
#  'crusty': 580,
#  'reasonable': 581,
#  'hard': 582,
#  'Chicken': 583,
#  'gooodd': 584,
#  'arrived': 585,
#  'please': 586,
#  'belly': 587,
#  'authentic': 588,
#  'placed': 589,
#  'Tried': 590,
#  'as': 591,
#  'fair': 592,
#  'Jamaican': 593,
#  'been-stepped-in-and-tracked-everywhere': 594,
#  'sucks': 595,
#  'duck': 596,
#  'climbing': 597,
#  'sound': 598,
#  'greasy': 599,
#  'fails': 600,
#  'dried': 601,
#  'stinks': 602,
#  'manager': 603,
#  'used': 604,
#  'pricey': 605,
#  'cavier': 606,
#  'Albondigas': 607,
#  'difference': 608,
#  'past': 609,
#  'Coming': 610,
#  'NYC': 611,
#  "''": 612,
#  'third': 613,
#  'strip': 614,
#  'These': 615,
#  'serve': 616,
#  'Cod': 617,
#  'downtown': 618,
#  'yukon': 619,
#  'Wonderful': 620,
#  'hope': 621,
#  'fried': 622,
#  'plastic': 623,
#  'attached': 624,
#  'added': 625,
#  'reading': 626,
#  '%': 627,
#  'son': 628,
#  'expanded': 629,
#  'Attack': 630,
#  'hereas': 631,
#  'serivce': 632,
#  'myself': 633,
#  'An': 634,
#  'ca': 635,
#  'second': 636,
#  'Why': 637,
#  'court': 638,
#  'extraordinary': 639,
#  'waitress': 640,
#  'Paying': 641,
#  'showed': 642,
#  'dude': 643,
#  'suggest': 644,
#  'blow': 645,
#  'fear': 646,
#  'obviously': 647,
#  'creamy': 648,
#  'double': 649,
#  'yellowtail': 650,
#  'sticks': 651,
#  'combo': 652,
#  'something': 653,
#  'flavored': 654,
#  'opinion': 655,
#  'transcendant': 656,
#  'Only': 657,
#  'known': 658,
#  'its': 659,
#  'stupid': 660,
#  'everyone': 661,
#  'Extremely': 662,
#  'while': 663,
#  'Pricing': 664,
#  'ethic': 665,
#  'plantains': 666,
#  'otherwise': 667,
#  'poorly': 668,
#  'seated': 669,
#  'think': 670,
#  'shoots': 671,
#  'LOVED': 672,
#  'book': 673,
#  'cool': 674,
#  'Mediterranean': 675,
#  'new': 676,
#  'read': 677,
#  'patron': 678,
#  'giant': 679,
#  "'s": 680,
#  'only': 681,
#  'Company': 682,
#  'Bellagio': 683,
#  'Thumbs': 684,
#  'pasta': 685,
#  'fo': 686,
#  'girlfriend': 687,
#  'Things': 688,
#  'imagination': 689,
#  'Vegas': 690,
#  'cafe': 691,
#  'Wo': 692,
#  'star': 693,
#  'sangria': 694,
#  'their': 695,
#  'lovely': 696,
#  'coconut': 697,
#  'reminds': 698,
#  'waited': 699,
#  'onion': 700,
#  'Philadelphia': 701,
#  'Strike': 702,
#  'article': 703,
#  'Kabuki': 704,
#  'movies': 705,
#  'when': 706,
#  'actual': 707,
#  'five': 708,
#  'bakery': 709,
#  'recommended': 710,
#  'Filet': 711,
#  'rare': 712,
#  'priced': 713,
#  'inside': 714,
#  'condiment': 715,
#  '40': 716,
#  'review': 717,
#  'Service': 718,
#  'Waitress': 719,
#  'Just': 720,
#  'Ramsey': 721,
#  'Bouchon': 722,
#  'liked': 723,
#  'thin': 724,
#  'Standard': 725,
#  'privileged': 726,
#  'thirty': 727,
#  'Wienerschnitzel': 728,
#  '.off': 729,
#  'may': 730,
#  'cashier': 731,
#  'pale': 732,
#  'vibe': 733,
#  'pastry': 734,
#  'Worse': 735,
#  'Pita': 736,
#  'works': 737,
#  'Caballero': 738,
#  'glad': 739,
#  'Damn': 740,
#  'sub-par': 741,
#  'atrocious': 742,
#  'Bisque': 743,
#  'Hot': 744,
#  'flavorless': 745,
#  'customize': 746,
#  'devine': 747,
#  'AN': 748,
#  'friend': 749,
#  'rushed': 750,
#  'hopes': 751,
#  'hamburger': 752,
#  'You': 753,
#  'week': 754,
#  '90': 755,
#  'decorated': 756,
#  'hand': 757,
#  'Reasonably': 758,
#  'anymore': 759,
#  '1.5lb': 760,
#  'revisiting': 761,
#  'inflate': 762,
#  'Halibut': 763,
#  'pissd': 764,
#  '40min': 765,
#  'Perhaps': 766,
#  'ourselves': 767,
#  'BEST': 768,
#  'beers': 769,
#  'pay': 770,
#  'swung': 771,
#  'dinners': 772,
#  'oven': 773,
#  'Cibo': 774,
#  'cheated': 775,
#  'In': 776,
#  'unbelievably': 777,
#  'water': 778,
#  'eat': 779,
#  'veal': 780,
#  'Cotta': 781,
#  'amazing': 782,
#  'lawyers': 783,
#  'vegan/veggie': 784,
#  'app': 785,
#  'Took': 786,
#  'returning': 787,
#  'Cape': 788,
#  'stood': 789,
#  'cooked': 790,
#  'CONCLUSION': 791,
#  'shots': 792,
#  'beautiful': 793,
#  'find': 794,
#  'tater': 795,
#  'tasty': 796,
#  'regular': 797,
#  'loving': 798,
#  'working/eating': 799,
#  'whether': 800,
#  'pita': 801,
#  'side': 802,
#  'texture': 803,
#  'customers': 804,
#  'if': 805,
#  'saffron': 806,
#  'tastings': 807,
#  'Lemon': 808,
#  'struggle': 809,
#  'unless': 810,
#  'mind': 811,
#  'wish': 812,
#  'refried': 813,
#  'Ians': 814,
#  'Please': 815,
#  'boba': 816,
#  'baklava': 817,
#  'Han': 818,
#  'recently': 819,
#  'appetizers': 820,
#  'Salad': 821,
#  'satisfied': 822,
#  'efficient': 823,
#  'VERY': 824,
#  'Main': 825,
#  'shower': 826,
#  'smoke': 827,
#  'up': 828,
#  'disgusted': 829,
#  'bathroom': 830,
#  'in-house': 831,
#  'wash': 832,
#  'lost': 833,
#  'FREEZING': 834,
#  'spends': 835,
#  'common': 836,
#  'underwhelming': 837,
#  'others': 838,
#  'vanilla': 839,
#  'frustrated': 840,
#  'BITCHES': 841,
#  'excellent': 842,
#  'oh': 843,
#  'mortified': 844,
#  '35': 845,
#  'case': 846,
#  'Steve': 847,
#  'professional': 848,
#  'curry': 849,
#  'decent': 850,
#  'Seriously': 851,
#  'establishment': 852,
#  'seemed': 853,
#  'Point': 854,
#  'Despite': 855,
#  'folks': 856,
#  'steakhouse': 857,
#  'done': 858,
#  'employee': 859,
#  'blows': 860,
#  'fellow': 861,
#  'dirty-': 862,
#  'happened': 863,
#  'ambience': 864,
#  'seriously': 865,
#  'then': 866,
#  'She': 867,
#  'wants': 868,
#  'breakfast/lunch': 869,
#  'Denny': 870,
#  'bartenders': 871,
#  'events': 872,
#  'turkey': 873,
#  'rude': 874,
#  'told': 875,
#  'bank': 876,
#  'chickens': 877,
#  'platter': 878,
#  'bird': 879,
#  'bits': 880,
#  'Furthermore': 881,
#  '4': 882,
#  'However': 883,
#  'color': 884,
#  'man': 885,
#  'seen': 886,
#  'portions': 887,
#  'Which': 888,
#  'rolls': 889,
#  'High-quality': 890,
#  'show': 891,
#  'ingredients': 892,
#  'freaking': 893,
#  'Left': 894,
#  'describing': 895,
#  'sporting': 896,
#  'sub': 897,
#  'choose': 898,
#  'saying': 899,
#  'medium': 900,
#  'AYCE': 901,
#  'Def': 902,
#  'nice': 903,
#  'use': 904,
#  'managed': 905,
#  'bottom': 906,
#  'Loved': 907,
#  'holiday': 908,
#  'disappointed': 909,
#  'anytime': 910,
#  'bug': 911,
#  'Perfect': 912,
#  'doing': 913,
#  'buffet': 914,
#  'dish': 915,
#  'Ironman': 916,
#  'plain': 917,
#  'gets': 918,
#  'every': 919,
#  'Buffet': 920,
#  'spot': 921,
#  'preparing': 922,
#  'reviewing..': 923,
#  'Palm': 924,
#  'putting': 925,
#  'drastically': 926,
#  'subpar': 927,
#  'have': 928,
#  'me..Bunch': 929,
#  'Very': 930,
#  'vodka': 931,
#  'rarely': 932,
#  'food/service': 933,
#  'overall': 934,
#  'I': 935,
#  'mid': 936,
#  'law': 937,
#  'tepid': 938,
#  'foods': 939,
#  's': 940,
#  'avocado': 941,
#  'peanut': 942,
#  'carbs': 943,
#  'Honestly': 944,
#  'far': 945,
#  'your': 946,
#  'sick': 947,
#  'equally': 948,
#  'going': 949,
#  'immediately': 950,
#  'or': 951,
#  'rate': 952,
#  'mood': 953,
#  'beer': 954,
#  'Would': 955,
#  'weekend': 956,
#  'top': 957,
#  'spaghetti': 958,
#  'Magic': 959,
#  'further': 960,
#  'Phenomenal': 961,
#  'absolutely': 962,
#  "'ll": 963,
#  'amount': 964,
#  'guess': 965,
#  'mall': 966,
#  'REAL': 967,
#  'until': 968,
#  'concept': 969,
#  'cheeseburger': 970,
#  'bartender': 971,
#  'Interesting': 972,
#  'driest': 973,
#  'Service-check': 974,
#  'Bussell': 975,
#  'jewel': 976,
#  'needs': 977,
#  'Definitely': 978,
#  'IT': 979,
#  'forth': 980,
#  'Needless': 981,
#  'soggy': 982,
#  'probably': 983,
#  'rings': 984,
#  'Ha': 985,
#  'come': 986,
#  'yay': 987,
#  'looked': 988,
#  'wildly': 989,
#  'favorite': 990,
#  'melt': 991,
#  'Not': 992,
#  'proclaimed': 993,
#  'between': 994,
#  'donut': 995,
#  'Mediocre': 996,
#  'Sauce': 997,
#  'oil': 998,
#  'succulent': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'IN',
#  1: 'deserves',
#  2: 'best',
#  3: 'reasons',
#  4: 'chow',
#  5: 'take',
#  6: 'pepper',
#  7: 'Really',
#  8: 'end',
#  9: 'Horrible',
#  10: 'Japanese',
#  11: 'Luke',
#  12: 'stuff',
#  13: 'older',
#  14: 'tragedy',
#  15: 'meals',
#  16: 'Experience',
#  17: 'Your',
#  18: 'pink',
#  19: 'batter',
#  20: 'disaster',
#  21: 'personally',
#  22: 'brunch',
#  23: 'perpared',
#  24: 'mistake',
#  25: 'crêpe',
#  26: 'worker',
#  27: 'Good',
#  28: 'regularly',
#  29: 'must-stop',
#  30: 'judging',
#  31: 'warnings',
#  32: 'fresh',
#  33: 'Crostini',
#  34: 'salt',
#  35: 'fairly',
#  36: 'melted',
#  37: 'gem',
#  38: 'crawfish',
#  39: 'tribute',
#  40: 'Overall',
#  41: 'money',
#  42: 'market',
#  43: 'lunch',
#  44: 'mussels',
#  45: 'Sun',
#  46: 'ahead',
#  47: 'Burrittos',
#  48: 'attitudes',
#  49: 'Madison',
#  50: 'beans',
#  51: 'Ambience',
#  52: 'Paradise',
#  53: 'Pizza',
#  54: 'summarize',
#  55: 'portion',
#  56: 'whenever',
#  57: 'before',
#  58: 'know',
#  59: 'not',
#  60: 'Firehouse',
#  61: 'Magazine',
#  62: 'awkwardly',
#  63: 'services',
#  64: 'ten',
#  65: 'six',
#  66: '10',
#  67: 'pepper..and',
#  68: 'GREAT',
#  69: 'Toast',
#  70: 'where',
#  71: 'simply',
#  72: 'Level',
#  73: 'hoping',
#  74: 'begin',
#  75: 'wonderful',
#  76: 'cakes',
#  77: 'Mandalay',
#  78: 'Tucson',
#  79: 'me',
#  80: 'chefs',
#  81: 'Eew',
#  82: 'crab',
#  83: 'fell',
#  84: 'pretty',
#  85: 'summary',
#  86: 'NONE',
#  87: 'kitchen',
#  88: 'feels',
#  89: 'Terrible',
#  90: 'Oh',
#  91: 'Pretty',
#  92: 'pack',
#  93: 'person',
#  94: 'enthusiastic',
#  95: 'dropped',
#  96: 'Will',
#  97: 'Greek',
#  98: 'patty',
#  99: 'without',
#  100: 'blandest',
#  101: 'huevos',
#  102: 'Hunan',
#  103: 'horrible',
#  104: 'classic',
#  105: 'sliced',
#  106: 'palate',
#  107: 'takeout',
#  108: 'gristle',
#  109: 'avoided',
#  110: 'black',
#  111: 'recent',
#  112: 'mmmm',
#  113: 'scallop',
#  114: 'Caesar',
#  115: 'ranch',
#  116: 'deal',
#  117: 'FLAVOR',
#  118: 'reminded',
#  119: 'salty',
#  120: 'opposed',
#  121: 'serves',
#  122: 'maintaining',
#  123: 'guys',
#  124: 'raspberry',
#  125: '7.85',
#  126: '.THE',
#  127: 'tapas',
#  128: 'ridiculous',
#  129: 'ordering',
#  130: 'last',
#  131: 'hour',
#  132: 'menu/',
#  133: 'quickly',
#  134: 'Cant',
#  135: 'crispy',
#  136: 'that',
#  137: 'giving',
#  138: 'BACK',
#  139: 'impeccable',
#  140: 'Christmas',
#  141: 'letting',
#  142: 'lighter',
#  143: 'Coffee',
#  144: 'olives',
#  145: 'time',
#  146: 'self',
#  147: 'saganaki',
#  148: 'first',
#  149: 'sexy',
#  150: 'jalapeno',
#  151: 'Worst',
#  152: 'gone',
#  153: 'There',
#  154: 'small',
#  155: 'seafood',
#  156: 'Prices',
#  157: 'compliments',
#  158: 'huge',
#  159: 'stay',
#  160: 'dishes',
#  161: 'getting',
#  162: 'crumby',
#  163: 'here',
#  164: 'send',
#  165: 'Sprouts',
#  166: 'wo',
#  167: 'entire',
#  168: 'left',
#  169: 'vegetarian',
#  170: 'mein',
#  171: 'disagree',
#  172: 'management',
#  173: 'beyond',
#  174: 'honor',
#  175: 'thanks',
#  176: 'sandwich',
#  177: 'Soups',
#  178: 'under',
#  179: 'Wife',
#  180: 'Bean',
#  181: 'sandwiches',
#  182: 'highlight',
#  183: 'orders',
#  184: 'pecan',
#  185: 'strange',
#  186: 'airline',
#  187: 'lighting',
#  188: 'One',
#  189: 'cook',
#  190: 'Buldogis',
#  191: 'found',
#  192: 'Before',
#  193: 'Chipotle',
#  194: 'went',
#  195: 'thinly',
#  196: 'eggplant',
#  197: 'living',
#  198: 'Awful',
#  199: 'trimmed',
#  200: 'touch',
#  201: 'dirty',
#  202: 'helped',
#  203: 'Up',
#  204: 'passed',
#  205: 'stretch',
#  206: 'sauce',
#  207: 'enough..',
#  208: 'Classy/warm',
#  209: 'EXPERIENCE',
#  210: 'fine',
#  211: 'gas',
#  212: 'seems',
#  213: 'way',
#  214: 'super',
#  215: 'caught',
#  216: 'Bachi',
#  217: 'delicious',
#  218: 'club',
#  219: 'delicate',
#  220: 'to',
#  221: 'RI',
#  222: 'trip',
#  223: 'douchey',
#  224: 'for',
#  225: 'grocery',
#  226: 'since',
#  227: 'cocktails',
#  228: 'haunt',
#  229: 'thinking',
#  230: 'tots',
#  231: 'couple',
#  232: 'Macarons',
#  233: 'mom',
#  234: 'screwed',
#  235: 'disgrace',
#  236: 'boot',
#  237: 'couples',
#  238: 'WAY',
#  239: 'given',
#  240: 'low',
#  241: 'we',
#  242: 'rich',
#  243: 'customer',
#  244: 'pancake',
#  245: 'apple',
#  246: 'Crystals',
#  247: 'friends',
#  248: 'employees',
#  249: 'complain',
#  250: 'nothing',
#  251: 'accountant',
#  252: 'ALL',
#  253: 'Waited',
#  254: 'bone',
#  255: "ya'all",
#  256: 'was',
#  257: 'much',
#  258: 'Unfortunately',
#  259: 'each',
#  260: 'one',
#  261: 'flavourful',
#  262: 'together',
#  263: 'drunk',
#  264: 'driving',
#  265: 'over-whelm',
#  266: 'largely',
#  267: 'summer',
#  268: 'tea',
#  269: 'outta',
#  270: 'vegetables',
#  271: 'drinks',
#  272: 'fare',
#  273: 'crisp',
#  274: 'make',
#  275: 'can',
#  276: 'Love',
#  277: 'cheek',
#  278: 'bathrooms',
#  279: 'spots',
#  280: 'nigiri',
#  281: 'continue',
#  282: 'THIS',
#  283: 'frozen',
#  284: 'refrained',
#  285: 'dripping',
#  286: 'ball',
#  287: 'daughter',
#  288: 'party',
#  289: 'owner/chef',
#  290: 'ache',
#  291: 'On',
#  292: 'taste',
#  293: 'Rick',
#  294: 'GC',
#  295: 'Went',
#  296: 'public',
#  297: 'brownish',
#  298: 'Of',
#  299: 'fillet',
#  300: 'spice',
#  301: 'yummy',
#  302: 'over',
#  303: 'latte',
#  304: 'desired',
#  305: 'year',
#  306: 'little',
#  307: 'Im',
#  308: 'dates',
#  309: 'offers',
#  310: 'Place',
#  311: 'meat',
#  312: 'fish',
#  313: 'Smashburger',
#  314: 'playing',
#  315: 'Then',
#  316: 'leather',
#  317: 'smeared',
#  318: 'anyone',
#  319: 'Delicious',
#  320: 'easily',
#  321: 'GO',
#  322: 'ever',
#  323: 'friendly',
#  324: 'PEOPLE',
#  325: 'listed',
#  326: 'brother',
#  327: 'break',
#  328: 'real',
#  329: 'sucker',
#  330: 'multi-grain',
#  331: 'asking',
#  332: 'ago',
#  333: 'editing',
#  334: 'lacked',
#  335: 'relaxed',
#  336: 'combination',
#  337: 'disapppointment',
#  338: 'dry',
#  339: 'place',
#  340: 'signs',
#  341: 'felt',
#  342: 'toro',
#  343: 'possible',
#  344: 'appalling',
#  345: 'shoe',
#  346: 'corn',
#  347: 'steaks',
#  348: 'eating',
#  349: 'Scottsdale',
#  350: 'theft',
#  351: 'all',
#  352: 'awkward',
#  353: 'recommendation',
#  354: 'tartare',
#  355: 'touched',
#  356: 'Disappointing',
#  357: 'live',
#  358: 'calligraphy',
#  359: 'special',
#  360: 'Frenchman',
#  361: 'least',
#  362: 'house',
#  363: 'pats',
#  364: 'T.',
#  365: 'might',
#  366: 'blanket',
#  367: 'gyros',
#  368: 'gave',
#  369: 'batch',
#  370: 'fail',
#  371: 'Cooked',
#  372: 'loudly',
#  373: 'looks',
#  374: 'For',
#  375: '!',
#  376: 'sorely',
#  377: 'tip',
#  378: 'speedy',
#  379: 'desserts',
#  380: 'Camelback',
#  381: 'stayed',
#  382: 'healthy',
#  383: 'bellies',
#  384: 'relocated',
#  385: 'Strip',
#  386: 'Eclectic',
#  387: 'play',
#  388: 'boy',
#  389: 'fondue',
#  390: 'WORST',
#  391: 'who',
#  392: 'things',
#  393: 'military',
#  394: 'thought',
#  395: 'need',
#  396: 'courteous',
#  397: 'wall',
#  398: 'stuffed',
#  399: 'drive',
#  400: 'WAAAAAAyyyyyyyyyy',
#  401: 'perfection',
#  402: 'Eve',
#  403: 'coupons',
#  404: 'mary',
#  405: '..went',
#  406: '*',
#  407: 'damn',
#  408: 'slaw',
#  409: 'publicly',
#  410: 'deuchebaggery',
#  411: 'STEP',
#  412: 'extra',
#  413: 'judge',
#  414: 'rancheros',
#  415: 'informative',
#  416: 'Hard',
#  417: 'imaginative',
#  418: 'rib',
#  419: 'pancakes',
#  420: 'charge',
#  421: 'Baseball',
#  422: 'fiancé',
#  423: 'down',
#  424: 'missed',
#  425: 'tiny',
#  426: 'Fantastic',
#  427: 'Highly',
#  428: 'Gyros',
#  429: 'Avoid',
#  430: 'kids',
#  431: 'reduction',
#  432: 'When',
#  433: 'wagyu',
#  434: 'trying',
#  435: 'duo',
#  436: 'meatballs',
#  437: 'Everything',
#  438: 'breaks',
#  439: 'Lobster',
#  440: 'Pros',
#  441: 'door',
#  442: 'out',
#  443: 'mouths',
#  444: 'wings',
#  445: 'checked',
#  446: 'REALLY',
#  447: 'heart',
#  448: 'closed',
#  449: 'Seat',
#  450: 'Never',
#  451: 'North',
#  452: 'warm',
#  453: 'ask',
#  454: 'Cartel',
#  455: 'soundtrack',
#  456: 'included',
#  457: 'pneumatic',
#  458: 'head',
#  459: 'meet',
#  460: 'work',
#  461: 'by',
#  462: 'deep',
#  463: 'Frozen',
#  464: 'helpful',
#  465: 'kid',
#  466: 'gold',
#  467: 'FLY',
#  468: 'expected',
#  469: 'shawarrrrrrma',
#  470: 'promptly',
#  471: 'carpaccio',
#  472: 'look',
#  473: 'prime',
#  474: 'writing',
#  475: 'patio',
#  476: 'mediocre',
#  477: 'effort',
#  478: 'crowd',
#  479: 'sat',
#  480: 'wide',
#  481: 'Heimer',
#  482: 'FS',
#  483: 'UNREAL',
#  484: 'Sour',
#  485: 'thrilled',
#  486: 'disrespected',
#  487: 'opportunity',
#  488: 'saving',
#  489: 'generous',
#  490: 'large',
#  491: 'nicest',
#  492: 'violinists',
#  493: 'happier',
#  494: 'Jenni',
#  495: 'you',
#  496: 'section',
#  497: 'hello',
#  498: 'besides',
#  499: 'rubber',
#  500: 'kind',
#  501: 'salsa',
#  502: 'Bland',
#  503: 'callings',
#  504: '70+',
#  505: 'Edinburgh',
#  506: 'block',
#  507: 'longer',
#  508: 'fluffy',
#  509: 'Nice',
#  510: 'cramming',
#  511: 'vinaigrette',
#  512: 'either',
#  513: 'EVER',
#  514: 'falafels',
#  515: 'his',
#  516: 'try',
#  517: 'realized',
#  518: 'FORWARD',
#  519: 'glance',
#  520: 'remember',
#  521: 'indoor',
#  522: 'decision',
#  523: 'disappointing',
#  524: '..there',
#  525: 'dedicated',
#  526: 'pace',
#  527: '-Drinks',
#  528: '2',
#  529: "'re",
#  530: 'handling',
#  531: 'ok',
#  532: 'watered',
#  533: 'owners',
#  534: 'hungry',
#  535: 'grossed',
#  536: 'seal',
#  537: 'massive',
#  538: 'Check',
#  539: 'Nobu',
#  540: 'disappointment',
#  541: 'fruit',
#  542: 'scene',
#  543: 'waiting',
#  544: 'once',
#  545: 'Restaurant',
#  546: 'Bay',
#  547: 'personable',
#  548: 'Lordy',
#  549: 'check',
#  550: 'of',
#  551: 'cant',
#  552: 'Joey',
#  553: 'fella',
#  554: 'flat',
#  555: 'banana',
#  556: 'Tasty',
#  557: 'complaints',
#  558: 'stir',
#  559: 'profiterole',
#  560: 'college',
#  561: 'dessert',
#  562: 'HAPPENED',
#  563: 'sunglasses',
#  564: 'today',
#  565: 'edible',
#  566: 'later',
#  567: 'hilarious',
#  568: 'highlighted',
#  569: 'email',
#  570: 'quaint',
#  571: 'NEVER',
#  572: 'class',
#  573: 'welcome',
#  574: 'Some',
#  575: 'Weird',
#  576: 'what',
#  577: 'angry',
#  578: 'same',
#  579: 'Roll',
#  580: 'crusty',
#  581: 'reasonable',
#  582: 'hard',
#  583: 'Chicken',
#  584: 'gooodd',
#  585: 'arrived',
#  586: 'please',
#  587: 'belly',
#  588: 'authentic',
#  589: 'placed',
#  590: 'Tried',
#  591: 'as',
#  592: 'fair',
#  593: 'Jamaican',
#  594: 'been-stepped-in-and-tracked-everywhere',
#  595: 'sucks',
#  596: 'duck',
#  597: 'climbing',
#  598: 'sound',
#  599: 'greasy',
#  600: 'fails',
#  601: 'dried',
#  602: 'stinks',
#  603: 'manager',
#  604: 'used',
#  605: 'pricey',
#  606: 'cavier',
#  607: 'Albondigas',
#  608: 'difference',
#  609: 'past',
#  610: 'Coming',
#  611: 'NYC',
#  612: "''",
#  613: 'third',
#  614: 'strip',
#  615: 'These',
#  616: 'serve',
#  617: 'Cod',
#  618: 'downtown',
#  619: 'yukon',
#  620: 'Wonderful',
#  621: 'hope',
#  622: 'fried',
#  623: 'plastic',
#  624: 'attached',
#  625: 'added',
#  626: 'reading',
#  627: '%',
#  628: 'son',
#  629: 'expanded',
#  630: 'Attack',
#  631: 'hereas',
#  632: 'serivce',
#  633: 'myself',
#  634: 'An',
#  635: 'ca',
#  636: 'second',
#  637: 'Why',
#  638: 'court',
#  639: 'extraordinary',
#  640: 'waitress',
#  641: 'Paying',
#  642: 'showed',
#  643: 'dude',
#  644: 'suggest',
#  645: 'blow',
#  646: 'fear',
#  647: 'obviously',
#  648: 'creamy',
#  649: 'double',
#  650: 'yellowtail',
#  651: 'sticks',
#  652: 'combo',
#  653: 'something',
#  654: 'flavored',
#  655: 'opinion',
#  656: 'transcendant',
#  657: 'Only',
#  658: 'known',
#  659: 'its',
#  660: 'stupid',
#  661: 'everyone',
#  662: 'Extremely',
#  663: 'while',
#  664: 'Pricing',
#  665: 'ethic',
#  666: 'plantains',
#  667: 'otherwise',
#  668: 'poorly',
#  669: 'seated',
#  670: 'think',
#  671: 'shoots',
#  672: 'LOVED',
#  673: 'book',
#  674: 'cool',
#  675: 'Mediterranean',
#  676: 'new',
#  677: 'read',
#  678: 'patron',
#  679: 'giant',
#  680: "'s",
#  681: 'only',
#  682: 'Company',
#  683: 'Bellagio',
#  684: 'Thumbs',
#  685: 'pasta',
#  686: 'fo',
#  687: 'girlfriend',
#  688: 'Things',
#  689: 'imagination',
#  690: 'Vegas',
#  691: 'cafe',
#  692: 'Wo',
#  693: 'star',
#  694: 'sangria',
#  695: 'their',
#  696: 'lovely',
#  697: 'coconut',
#  698: 'reminds',
#  699: 'waited',
#  700: 'onion',
#  701: 'Philadelphia',
#  702: 'Strike',
#  703: 'article',
#  704: 'Kabuki',
#  705: 'movies',
#  706: 'when',
#  707: 'actual',
#  708: 'five',
#  709: 'bakery',
#  710: 'recommended',
#  711: 'Filet',
#  712: 'rare',
#  713: 'priced',
#  714: 'inside',
#  715: 'condiment',
#  716: '40',
#  717: 'review',
#  718: 'Service',
#  719: 'Waitress',
#  720: 'Just',
#  721: 'Ramsey',
#  722: 'Bouchon',
#  723: 'liked',
#  724: 'thin',
#  725: 'Standard',
#  726: 'privileged',
#  727: 'thirty',
#  728: 'Wienerschnitzel',
#  729: '.off',
#  730: 'may',
#  731: 'cashier',
#  732: 'pale',
#  733: 'vibe',
#  734: 'pastry',
#  735: 'Worse',
#  736: 'Pita',
#  737: 'works',
#  738: 'Caballero',
#  739: 'glad',
#  740: 'Damn',
#  741: 'sub-par',
#  742: 'atrocious',
#  743: 'Bisque',
#  744: 'Hot',
#  745: 'flavorless',
#  746: 'customize',
#  747: 'devine',
#  748: 'AN',
#  749: 'friend',
#  750: 'rushed',
#  751: 'hopes',
#  752: 'hamburger',
#  753: 'You',
#  754: 'week',
#  755: '90',
#  756: 'decorated',
#  757: 'hand',
#  758: 'Reasonably',
#  759: 'anymore',
#  760: '1.5lb',
#  761: 'revisiting',
#  762: 'inflate',
#  763: 'Halibut',
#  764: 'pissd',
#  765: '40min',
#  766: 'Perhaps',
#  767: 'ourselves',
#  768: 'BEST',
#  769: 'beers',
#  770: 'pay',
#  771: 'swung',
#  772: 'dinners',
#  773: 'oven',
#  774: 'Cibo',
#  775: 'cheated',
#  776: 'In',
#  777: 'unbelievably',
#  778: 'water',
#  779: 'eat',
#  780: 'veal',
#  781: 'Cotta',
#  782: 'amazing',
#  783: 'lawyers',
#  784: 'vegan/veggie',
#  785: 'app',
#  786: 'Took',
#  787: 'returning',
#  788: 'Cape',
#  789: 'stood',
#  790: 'cooked',
#  791: 'CONCLUSION',
#  792: 'shots',
#  793: 'beautiful',
#  794: 'find',
#  795: 'tater',
#  796: 'tasty',
#  797: 'regular',
#  798: 'loving',
#  799: 'working/eating',
#  800: 'whether',
#  801: 'pita',
#  802: 'side',
#  803: 'texture',
#  804: 'customers',
#  805: 'if',
#  806: 'saffron',
#  807: 'tastings',
#  808: 'Lemon',
#  809: 'struggle',
#  810: 'unless',
#  811: 'mind',
#  812: 'wish',
#  813: 'refried',
#  814: 'Ians',
#  815: 'Please',
#  816: 'boba',
#  817: 'baklava',
#  818: 'Han',
#  819: 'recently',
#  820: 'appetizers',
#  821: 'Salad',
#  822: 'satisfied',
#  823: 'efficient',
#  824: 'VERY',
#  825: 'Main',
#  826: 'shower',
#  827: 'smoke',
#  828: 'up',
#  829: 'disgusted',
#  830: 'bathroom',
#  831: 'in-house',
#  832: 'wash',
#  833: 'lost',
#  834: 'FREEZING',
#  835: 'spends',
#  836: 'common',
#  837: 'underwhelming',
#  838: 'others',
#  839: 'vanilla',
#  840: 'frustrated',
#  841: 'BITCHES',
#  842: 'excellent',
#  843: 'oh',
#  844: 'mortified',
#  845: '35',
#  846: 'case',
#  847: 'Steve',
#  848: 'professional',
#  849: 'curry',
#  850: 'decent',
#  851: 'Seriously',
#  852: 'establishment',
#  853: 'seemed',
#  854: 'Point',
#  855: 'Despite',
#  856: 'folks',
#  857: 'steakhouse',
#  858: 'done',
#  859: 'employee',
#  860: 'blows',
#  861: 'fellow',
#  862: 'dirty-',
#  863: 'happened',
#  864: 'ambience',
#  865: 'seriously',
#  866: 'then',
#  867: 'She',
#  868: 'wants',
#  869: 'breakfast/lunch',
#  870: 'Denny',
#  871: 'bartenders',
#  872: 'events',
#  873: 'turkey',
#  874: 'rude',
#  875: 'told',
#  876: 'bank',
#  877: 'chickens',
#  878: 'platter',
#  879: 'bird',
#  880: 'bits',
#  881: 'Furthermore',
#  882: '4',
#  883: 'However',
#  884: 'color',
#  885: 'man',
#  886: 'seen',
#  887: 'portions',
#  888: 'Which',
#  889: 'rolls',
#  890: 'High-quality',
#  891: 'show',
#  892: 'ingredients',
#  893: 'freaking',
#  894: 'Left',
#  895: 'describing',
#  896: 'sporting',
#  897: 'sub',
#  898: 'choose',
#  899: 'saying',
#  900: 'medium',
#  901: 'AYCE',
#  902: 'Def',
#  903: 'nice',
#  904: 'use',
#  905: 'managed',
#  906: 'bottom',
#  907: 'Loved',
#  908: 'holiday',
#  909: 'disappointed',
#  910: 'anytime',
#  911: 'bug',
#  912: 'Perfect',
#  913: 'doing',
#  914: 'buffet',
#  915: 'dish',
#  916: 'Ironman',
#  917: 'plain',
#  918: 'gets',
#  919: 'every',
#  920: 'Buffet',
#  921: 'spot',
#  922: 'preparing',
#  923: 'reviewing..',
#  924: 'Palm',
#  925: 'putting',
#  926: 'drastically',
#  927: 'subpar',
#  928: 'have',
#  929: 'me..Bunch',
#  930: 'Very',
#  931: 'vodka',
#  932: 'rarely',
#  933: 'food/service',
#  934: 'overall',
#  935: 'I',
#  936: 'mid',
#  937: 'law',
#  938: 'tepid',
#  939: 'foods',
#  940: 's',
#  941: 'avocado',
#  942: 'peanut',
#  943: 'carbs',
#  944: 'Honestly',
#  945: 'far',
#  946: 'your',
#  947: 'sick',
#  948: 'equally',
#  949: 'going',
#  950: 'immediately',
#  951: 'or',
#  952: 'rate',
#  953: 'mood',
#  954: 'beer',
#  955: 'Would',
#  956: 'weekend',
#  957: 'top',
#  958: 'spaghetti',
#  959: 'Magic',
#  960: 'further',
#  961: 'Phenomenal',
#  962: 'absolutely',
#  963: "'ll",
#  964: 'amount',
#  965: 'guess',
#  966: 'mall',
#  967: 'REAL',
#  968: 'until',
#  969: 'concept',
#  970: 'cheeseburger',
#  971: 'bartender',
#  972: 'Interesting',
#  973: 'driest',
#  974: 'Service-check',
#  975: 'Bussell',
#  976: 'jewel',
#  977: 'needs',
#  978: 'Definitely',
#  979: 'IT',
#  980: 'forth',
#  981: 'Needless',
#  982: 'soggy',
#  983: 'probably',
#  984: 'rings',
#  985: 'Ha',
#  986: 'come',
#  987: 'yay',
#  988: 'looked',
#  989: 'wildly',
#  990: 'favorite',
#  991: 'melt',
#  992: 'Not',
#  993: 'proclaimed',
#  994: 'between',
#  995: 'donut',
#  996: 'Mediocre',
#  997: 'Sauce',
#  998: 'oil',
#  999: 'succulent',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            '''自行填入'''
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
